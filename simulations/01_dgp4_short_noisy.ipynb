# %% [markdown]
# # BBEATSx Phase 3: Decomposition Fidelity & Component UQ — DGP 4
#
# This notebook validates BBEATSx on **DGP 4: Short + Noisy (small-n, high-noise)**.
# It measures the forecasting calibration battery and the empirical coverage of component-level credible bands in a high-noise, short series regime.
#
# ## Google Colab Setup

# %%
# Check if running in Google Colab
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    print("Running in Google Colab. Setting up workspace...")
    import os
    if not os.path.abspath(".").endswith("simulations"):
        if not os.path.exists("BBEATSx"):
            # !git clone https://github.com/hugogobato/BBEATSx.git
        # !pip install ./BBEATSx
        # %cd BBEATSx/simulations
    else:
        print("Already in simulations directory.")

import sys
import os
sys.path.append(os.path.abspath("."))
sys.path.append(os.path.abspath(".."))
# Out:
# Running in Google Colab. Setting up workspace...
# Cloning into 'BBEATSx'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 59 (delta 14), reused 52 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (59/59), 61.84 KiB | 3.86 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Processing ./BBEATSx
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from bbeatsx==0.1.0) (2.0.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.12/dist-packages (from bbeatsx==0.1.0) (1.16.3)
# Building wheels for collected packages: bbeatsx
#   Building wheel for bbeatsx (pyproject.toml) ... done
#   Created wheel for bbeatsx: filename=bbeatsx-0.1.0-py3-none-any.whl size=43805 sha256=1e20b479a0e517ef5125724d1e4e3bb3baa04d2742723b69ff48c398f015411c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4li8r6vr/wheels/56/65/89/682968e55e85784c7ae1d0dfd917fdbd4d9c71ec4a8220358b
# Successfully built bbeatsx
# Installing collected packages: bbeatsx
# Successfully installed bbeatsx-0.1.0
# /content/BBEATSx/simulations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bbeatsx import BBEATSx, make_config
import utils

# %% [markdown]
# ## Simulation Configuration

# %%
NUM_SIMULATIONS = 100  # Set to 100 for final results on Colab
HORIZON = 20
LEVEL = 0.95
print(f"Running {NUM_SIMULATIONS} trials for DGP 4...")
# Out:
# Running 100 trials for DGP 4...

# %% [markdown]
# ## Run Simulations

# %%
dgp4_forecasts = []
dgp4_components = []

for i in range(NUM_SIMULATIONS):
    t, y, true_comps = utils.generate_dgp4(n=80, seed=i)
    n_train = len(y) - HORIZON
    y_train, y_test = y[:n_train], y[n_train:]

    cfg = make_config(
        periods=[(4, 1)],
        lags=(),
        trend="spline",
        errors="homo",
        num_gfr=50,
        num_burnin=200,
        num_mcmc=1000,
        seed=i
    )

    model = BBEATSx(cfg).fit(y_train)
    fc = model.forecast(HORIZON)

    dgp4_forecasts.append(utils.evaluate_forecast(y_test, fc, y_train, level=LEVEL))

    s = model.sampler_
    mean, std = s.y_mean_, s.y_std_
    in_sample_draws = s.in_sample_components()
    pred_in_sample = {
        "trend": mean + std * in_sample_draws["trend"],
        "seasonal": std * in_sample_draws["seasonal"],
        "generic": std * in_sample_draws["generic"]
    }
    comp_metrics_in = utils.evaluate_component_fidelity(
        true_comps, pred_in_sample, offset=s.fs.row_offset, level=LEVEL
    )

    pred_out_sample = {
        "trend": fc.components["trend"],
        "seasonal": fc.components["seasonal"],
        "generic": fc.components["generic"]
    }
    true_out_comps = {k: v[n_train:] for k, v in true_comps.items()}
    comp_metrics_out = utils.evaluate_component_fidelity(
        true_out_comps, pred_out_sample, offset=0, level=LEVEL
    )

    dgp4_components.append({
        "in_sample": comp_metrics_in,
        "out_sample": comp_metrics_out
    })

    if (i + 1) % 10 == 0:
        print(f"  Completed trial {i + 1}/{NUM_SIMULATIONS}")
# Out:
#   Completed trial 10/100
#   Completed trial 20/100
#   Completed trial 30/100
#   Completed trial 40/100
#   Completed trial 50/100
#   Completed trial 60/100
#   Completed trial 70/100
#   Completed trial 80/100
#   Completed trial 90/100
#   Completed trial 100/100

# %% [markdown]
# ## Results Summary

# %%
df_fc4 = pd.DataFrame(dgp4_forecasts)
print("\n--- DGP 4 Forecasting Calibration Battery ---")
print(df_fc4.mean().to_frame("Mean Metric"))

comp_in_rmse = {k: np.mean([t["in_sample"][k]["rmse"] for t in dgp4_components]) for k in ["trend", "seasonal", "generic"]}
comp_in_cov = {k: np.mean([t["in_sample"][k]["coverage"] for t in dgp4_components]) for k in ["trend", "seasonal", "generic"]}
comp_out_rmse = {k: np.mean([t["out_sample"][k]["rmse"] for t in dgp4_components]) for k in ["trend", "seasonal", "generic"]}
comp_out_cov = {k: np.mean([t["out_sample"][k]["coverage"] for t in dgp4_components]) for k in ["trend", "seasonal", "generic"]}

df_comp4 = pd.DataFrame({
    "In-Sample RMSE": comp_in_rmse,
    "In-Sample Coverage (95%)": comp_in_cov,
    "Out-of-Sample RMSE": comp_out_rmse,
    "Out-of-Sample Coverage (95%)": comp_out_cov
})
print("\n--- DGP 4 Component Fidelity (Plan §3.2) ---")
print(df_comp4)

# Save evaluation metrics to CSV files
df_fc4.to_csv("dgp4_bbeatsx_forecast_eval.csv", index_label="trial")

comp_rows = []
for idx, c in enumerate(dgp4_components):
    row = {
        "trial": idx
    }
    for sample in ["in_sample", "out_sample"]:
        for comp in ["trend", "seasonal", "generic"]:
            if comp in c[sample]:
                row[f"{sample}_{comp}_rmse"] = c[sample][comp]["rmse"]
                row[f"{sample}_{comp}_coverage"] = c[sample][comp]["coverage"]
    comp_rows.append(row)
df_comp_all = pd.DataFrame(comp_rows)
df_comp_all.to_csv("dgp4_bbeatsx_component_eval.csv", index=False)
print("Saved evaluation metrics to CSV files!")
# Out:
# --- DGP 4 Forecasting Calibration Battery ---
#                 Mean Metric
# rmse               1.456356
# smape             73.716303
# mase               0.771117
# crps               0.869685
# pinball            0.455542
# coverage           0.963500
# interval_score     7.948503
#
# --- DGP 4 Component Fidelity (Plan §3.2) ---
#           In-Sample RMSE  In-Sample Coverage (95%)  Out-of-Sample RMSE  \
# trend           0.607025                  0.988333            0.791571
# seasonal        0.640547                  0.993833            0.634718
# generic         1.166126                  0.000000            1.155066
#
#           Out-of-Sample Coverage (95%)
# trend                           0.9945
# seasonal                        0.9950
# generic                         0.0000
# Saved evaluation metrics to CSV files!

# %% [markdown]
# ## Visualizations

# %%
from bbeatsx.interpret import plot_decomposition

fig, ax = plt.subplots(4, 1, figsize=(10, 8), sharex=True)
plot_decomposition(model.sampler_, level=LEVEL, ax=ax)
ax[0].set_title("BBEATSx Component Decomposition with 90% Credible Bands (DGP 4)")
plt.tight_layout()
plt.show()
